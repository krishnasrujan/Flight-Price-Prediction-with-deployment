# %%
import pandas as pd 
import numpy as np

# %%
train_data = pd.read_excel('C:/Users/Srujan/Documents/Datasets/flight_price/Data_Train.xlsx',parse_dates=['Date_of_Journey'])
train_data
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      2019-03-24  Banglore   New Delhi
# 1        Air India      2019-01-05   Kolkata    Banglore
# 2      Jet Airways      2019-09-06     Delhi      Cochin
# 3           IndiGo      2019-12-05   Kolkata    Banglore
# 4           IndiGo      2019-01-03  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia      2019-09-04   Kolkata    Banglore
# 10679    Air India      2019-04-27   Kolkata    Banglore
# 10680  Jet Airways      2019-04-27  Banglore       Delhi
# 10681      Vistara      2019-01-03  Banglore   New Delhi
# 10682    Air India      2019-09-05     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %%
train_data.info()
#no null values and all independent features are are object type and dependent feature is integer type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  datetime64[ns]
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(9)
# memory usage: 918.2+ KB

# %%
train_data['Additional_Info'].value_counts()
# Out:
# No info                         8345
# In-flight meal not included     1982
# No check-in baggage included     320
# 1 Long layover                    19
# Change airports                    7
# Business class                     4
# No Info                            3
# Red-eye flight                     1
# 1 Short layover                    1
# 2 Long layover                     1
# Name: Additional_Info, dtype: int64

# %%
train_data['Airline'].value_counts()
# Out:
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1752
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: Airline, dtype: int64

# %%
train_data = train_data[(train_data.Airline != 'Jet Airways') & (train_data.Airline != 'Jet Airways Business')]
train_data.reset_index(drop=True,inplace=True)

# %%
train_data
# Out:
#         Airline Date_of_Journey    Source Destination                  Route  \
# 0        IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1     Air India      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2        IndiGo      2019-12-05   Kolkata    Banglore        CCU → NAG → BLR
# 3        IndiGo      2019-01-03  Banglore   New Delhi        BLR → NAG → DEL
# 4      SpiceJet      2019-06-24   Kolkata    Banglore              CCU → BLR
# ...         ...             ...       ...         ...                    ...
# 6823   SpiceJet      2019-05-21  Banglore       Delhi              BLR → DEL
# 6824   Air Asia      2019-09-04   Kolkata    Banglore              CCU → BLR
# 6825  Air India      2019-04-27   Kolkata    Banglore              CCU → BLR
# 6826    Vistara      2019-01-03  Banglore   New Delhi              BLR → DEL
# 6827  Air India      2019-09-05     Delhi      Cochin  DEL → GOI → BOM → COK
#
#      Dep_Time  Arrival_Time Duration Total_Stops  \
# 0       22:20  01:10 22 Mar   2h 50m    non-stop
# 1       05:50         13:15   7h 25m     2 stops
# 2       18:05         23:30   5h 25m      1 stop
# 3       16:50         21:35   4h 45m      1 stop
# 4       09:00         11:25   2h 25m    non-stop
# ...       ...           ...      ...         ...
# 6823    05:55         08:35   2h 40m    non-stop
# 6824    19:55         22:25   2h 30m    non-stop
# 6825    20:45         23:20   2h 35m    non-stop
# 6826    11:30         14:10   2h 40m    non-stop
# 6827    10:55         19:15   8h 20m     2 stops
#
#                    Additional_Info  Price
# 0                          No info   3897
# 1                          No info   7662
# 2                          No info   6218
# 3                          No info  13302
# 4                          No info   3873
# ...                            ...    ...
# 6823  No check-in baggage included   3257
# 6824                       No info   4107
# 6825                       No info   4145
# 6826                       No info  12648
# 6827                       No info  11753
#
# [6828 rows x 11 columns]

# %%
# Droppin Route and Additional info columns
train_data.drop(['Route','Additional_Info'],axis=1,inplace=True)
# Out:
# C:\Users\Srujan\Anaconda\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %% [markdown]
# Departure time and Arrival time are strings. We need to extract hour and minute from both the columns

# %%
# Departure time is when a plane leaves the gate. 
# Similar to Date_of_Journey we can extract values from Dep_Time

# Extracting Hours
train_data["Dep_hour"] = pd.to_datetime(train_data["Dep_Time"]).dt.hour

# Extracting Minutes
train_data["Dep_min"] = pd.to_datetime(train_data["Dep_Time"]).dt.minute

# Now we can drop Dep_Time as it is of no use
train_data.drop(["Dep_Time"], axis = 1, inplace = True)


train_data["Dep_hour"] = train_data["Dep_hour"].astype(np.int16)
train_data["Dep_min"] = train_data["Dep_min"].astype(np.int16)
# Out:
# C:\Users\Srujan\Anaconda\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Srujan\Anaconda\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Srujan\Anaconda\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Srujan\Anaconda\anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app

# %%
# Arrival time is when the plane pulls up to the gate.
# Similar to Date_of_Journey we can extract values from Arrival_Time

# Extracting Hours
train_data["Arrival_hour"] = pd.to_datetime(train_data.Arrival_Time).dt.hour

# Extracting Minutes
train_data["Arrival_min"] = pd.to_datetime(train_data.Arrival_Time).dt.minute

# Now we can drop Arrival_Time as it is of no use
train_data.drop(["Arrival_Time"], axis = 1, inplace = True)


train_data["Arrival_hour"] = train_data["Arrival_hour"].astype(np.int16)
train_data["Arrival_min"] = train_data["Arrival_min"].astype(np.int16)
# Out:
# C:\Users\Srujan\Anaconda\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Srujan\Anaconda\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Srujan\Anaconda\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Srujan\Anaconda\anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app

# %% [markdown]
# Extracting journey date, journey month and journey day(day of the week) from Date_of_Journey column and dropping that column after extracting.

# %%
train_data['Jounrey_date'] = train_data['Date_of_Journey'].dt.day
train_data['Jounrey_month'] = train_data['Date_of_Journey'].dt.month
train_data['Journey_day'] = train_data['Date_of_Journey'].dt.dayofweek
train_data.drop('Date_of_Journey',axis=1,inplace=True)
train_data
# Out:
# C:\Users\Srujan\Anaconda\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Srujan\Anaconda\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Srujan\Anaconda\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#         Airline    Source Destination Duration Total_Stops  Price  Dep_hour  \
# 0        IndiGo  Banglore   New Delhi   2h 50m    non-stop   3897        22
# 1     Air India   Kolkata    Banglore   7h 25m     2 stops   7662         5
# 2        IndiGo   Kolkata    Banglore   5h 25m      1 stop   6218        18
# 3        IndiGo  Banglore   New Delhi   4h 45m      1 stop  13302        16
# 4      SpiceJet   Kolkata    Banglore   2h 25m    non-stop   3873         9
# ...         ...       ...         ...      ...         ...    ...       ...
# 6823   SpiceJet  Banglore       Delhi   2h 40m    non-stop   3257         5
# 6824   Air Asia   Kolkata    Banglore   2h 30m    non-stop   4107        19
# 6825  Air India   Kolkata    Banglore   2h 35m    non-stop   4145        20
# 6826    Vistara  Banglore   New Delhi   2h 40m    non-stop  12648        11
# 6827  Air India     Delhi      Cochin   8h 20m     2 stops  11753        10
#
#       Dep_min  Arrival_hour  Arrival_min  Jounrey_date  Jounrey_month  \
# 0          20             1           10            24              3
# 1          50            13           15             5              1
# 2           5            23           30             5             12
# 3          50            21           35             3              1
# 4           0            11           25            24              6
# ...       ...           ...          ...           ...            ...
# 6823       55             8           35            21              5
# 6824       55            22           25             4              9
# 6825       45            23           20            27              4
# 6826       30            14           10             3              1
# 6827       55            19           15             5              9
#
#       Journey_day
# 0               6
# 1               5
# 2               3
# 3               3
# 4               0
# ...           ...
# 6823            1
# 6824            2
# 6825            5
# 6826            3
# 6827            3
#
# [6828 rows x 13 columns]

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6828 entries, 0 to 6827
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Airline        6828 non-null   object
#  1   Source         6828 non-null   object
#  2   Destination    6828 non-null   object
#  3   Duration       6828 non-null   object
#  4   Total_Stops    6827 non-null   object
#  5   Price          6828 non-null   int64
#  6   Dep_hour       6828 non-null   int16
#  7   Dep_min        6828 non-null   int16
#  8   Arrival_hour   6828 non-null   int16
#  9   Arrival_min    6828 non-null   int16
#  10  Jounrey_date   6828 non-null   int64
#  11  Jounrey_month  6828 non-null   int64
#  12  Journey_day    6828 non-null   int64
# dtypes: int16(4), int64(4), object(5)
# memory usage: 533.6+ KB

# %%
train_data['Total_Stops'] = train_data['Total_Stops'].fillna(train_data['Total_Stops'].mode()[0])
# Out:
# C:\Users\Srujan\Anaconda\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Creating a new duration column. Even tough duration column is available, it is a string. We will find an easy way to extract the duration from departure time and arrival time.

# %%
def create_duration_time(data):
    for i in range(data.shape[0]):
        if data['Dep_hour'][i]>data['Arrival_hour'][i]:
            hours = data['Arrival_hour'][i]+24 - data['Dep_hour'][i]
        else:
            hours = data['Arrival_hour'][i] - data['Dep_hour'][i]

        minutes = data['Arrival_min'][i] - data['Dep_min'][i]

        data['Duration'][i] = hours*60 + minutes
    return data
    
train_data = create_duration_time(train_data)
train_data
# Out:
# C:\Users\Srujan\Anaconda\anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\Srujan\Anaconda\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
#         Airline    Source Destination Duration Total_Stops  Price  Dep_hour  \
# 0        IndiGo  Banglore   New Delhi      170    non-stop   3897        22
# 1     Air India   Kolkata    Banglore      445     2 stops   7662         5
# 2        IndiGo   Kolkata    Banglore      325      1 stop   6218        18
# 3        IndiGo  Banglore   New Delhi      285      1 stop  13302        16
# 4      SpiceJet   Kolkata    Banglore      145    non-stop   3873         9
# ...         ...       ...         ...      ...         ...    ...       ...
# 6823   SpiceJet  Banglore       Delhi      160    non-stop   3257         5
# 6824   Air Asia   Kolkata    Banglore      150    non-stop   4107        19
# 6825  Air India   Kolkata    Banglore      155    non-stop   4145        20
# 6826    Vistara  Banglore   New Delhi      160    non-stop  12648        11
# 6827  Air India     Delhi      Cochin      500     2 stops  11753        10
#
#       Dep_min  Arrival_hour  Arrival_min  Jounrey_date  Jounrey_month  \
# 0          20             1           10            24              3
# 1          50            13           15             5              1
# 2           5            23           30             5             12
# 3          50            21           35             3              1
# 4           0            11           25            24              6
# ...       ...           ...          ...           ...            ...
# 6823       55             8           35            21              5
# 6824       55            22           25             4              9
# 6825       45            23           20            27              4
# 6826       30            14           10             3              1
# 6827       55            19           15             5              9
#
#       Journey_day
# 0               6
# 1               5
# 2               3
# 3               3
# 4               0
# ...           ...
# 6823            1
# 6824            2
# 6825            5
# 6826            3
# 6827            3
#
# [6828 rows x 13 columns]

# %%
train_data['Total_Stops'].replace({'non-stop':0,'1 stop':1,'2 stops':2,'3 stops':3,'4 stops':4},inplace=True)
train_data
# Out:
# C:\Users\Srujan\Anaconda\anaconda3\lib\site-packages\pandas\core\generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
#         Airline    Source Destination Duration  Total_Stops  Price  Dep_hour  \
# 0        IndiGo  Banglore   New Delhi      170          0.0   3897        22
# 1     Air India   Kolkata    Banglore      445          2.0   7662         5
# 2        IndiGo   Kolkata    Banglore      325          1.0   6218        18
# 3        IndiGo  Banglore   New Delhi      285          1.0  13302        16
# 4      SpiceJet   Kolkata    Banglore      145          0.0   3873         9
# ...         ...       ...         ...      ...          ...    ...       ...
# 6823   SpiceJet  Banglore       Delhi      160          0.0   3257         5
# 6824   Air Asia   Kolkata    Banglore      150          0.0   4107        19
# 6825  Air India   Kolkata    Banglore      155          0.0   4145        20
# 6826    Vistara  Banglore   New Delhi      160          0.0  12648        11
# 6827  Air India     Delhi      Cochin      500          2.0  11753        10
#
#       Dep_min  Arrival_hour  Arrival_min  Jounrey_date  Jounrey_month  \
# 0          20             1           10            24              3
# 1          50            13           15             5              1
# 2           5            23           30             5             12
# 3          50            21           35             3              1
# 4           0            11           25            24              6
# ...       ...           ...          ...           ...            ...
# 6823       55             8           35            21              5
# 6824       55            22           25             4              9
# 6825       45            23           20            27              4
# 6826       30            14           10             3              1
# 6827       55            19           15             5              9
#
#       Journey_day
# 0               6
# 1               5
# 2               3
# 3               3
# 4               0
# ...           ...
# 6823            1
# 6824            2
# 6825            5
# 6826            3
# 6827            3
#
# [6828 rows x 13 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# From graph we can see that Jet Airways Business have the highest Price.
# Apart from the first Airline almost all are having similar median

# Airline vs Price
sns.catplot(y = "Price", x = "Airline", data = train_data.sort_values("Price", ascending = False), kind="boxen", height = 6, aspect = 3)

# %%
# Airline vs Price
sns.catplot(y = "Price", x = "Total_Stops", data = train_data.sort_values("Price", ascending = False), kind="boxen", height = 6, aspect = 3)

# %%
sns.heatmap(train_data.corr())

# %%
sns.scatterplot(x='Duration',y='Price',data=train_data,hue='Airline')

# %% [markdown]
# ## Feature Selection

# %%
X=train_data.copy()
y=X['Price']
X = X.iloc[:,3:]
X.drop(['Price'],axis=1,inplace=True)
X.head()
# Out:
#   Duration  Total_Stops  Dep_hour  Dep_min  Arrival_hour  Arrival_min  \
# 0      170          0.0        22       20             1           10
# 1      445          2.0         5       50            13           15
# 2      325          1.0        18        5            23           30
# 3      285          1.0        16       50            21           35
# 4      145          0.0         9        0            11           25
#
#    Jounrey_date  Jounrey_month  Journey_day
# 0            24              3            6
# 1             5              1            5
# 2             5             12            3
# 3             3              1            3
# 4            24              6            0

# %%
X.isnull().any()
# Out:
# Duration         False
# Total_Stops      False
# Dep_hour         False
# Dep_min          False
# Arrival_hour     False
# Arrival_min      False
# Jounrey_date     False
# Jounrey_month    False
# Journey_day      False
# dtype: bool

# %%
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeRegressor

# %%
model_dt = DecisionTreeRegressor()
rfe = RFE(estimator=model_dt, n_features_to_select=1, step=1)
rfe.fit(X,y)
# Out:
# RFE(estimator=DecisionTreeRegressor(), n_features_to_select=1)

# %%
rfe.ranking_
# Out:
# array([2, 1, 6, 5, 4, 8, 3, 7, 9])

# %%
X.columns
# Out:
# Index(['Duration', 'Total_Stops', 'Dep_hour', 'Dep_min', 'Arrival_hour',
#        'Arrival_min', 'Jounrey_date', 'Jounrey_month', 'Journey_day'],
#       dtype='object')

# %%
for rank, col in zip(rfe.ranking_,X.columns):
    print(rank, col)
# Out:
# 2 Duration
# 1 Total_Stops
# 6 Dep_hour
# 5 Dep_min
# 4 Arrival_hour
# 8 Arrival_min
# 3 Jounrey_date
# 7 Jounrey_month
# 9 Journey_day

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regres
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-43-7af3e667f52b> in <module>
#       1 from sklearn.feature_selection import SelectKBest
# ----> 2 from sklearn.feature_selection import f_regres
#
# ImportError: cannot import name 'f_regres' from 'sklearn.feature_selection' (C:\Users\Srujan\Anaconda\anaconda3\lib\site-packages\sklearn\feature_selection\__init__.py)

# %%
fs = SelectKBest(score_func=chi2, k=8)
apply feature selection
X = fs.fit_transform(X, y)
print(test.columns[fs.get_support()])

# %%
#test= fs.transform(test)
#print(X.shape)

# %%
#fs.get_support()

# %%
#fs.get_params()
